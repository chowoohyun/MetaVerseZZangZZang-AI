# %%
from google_play_scraper import Sort, reviews_all
import pandas as pd
import numpy as np

result = reviews_all(
    'com.google.android.apps.meetings',
    sleep_milliseconds=0, # defaults to 0
    lang='kr', # defaults to 'en'
    country='kr', # defaults to 'us'
    count= 3,
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with= 0 # defaults to None(means all score)
)

df_busu = pd.DataFrame(np.array(result), columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId         userName  \
# 0  18664340-6e1b-4298-9b86-9e25daba80b0   Melanie Zamzow
# 1  5d26c686-0aba-4b75-88f0-22f3b9d95d99         Jim Shea
# 2  aaad311c-5253-465c-854b-26b9d2b44509  Kevin Levington
# 3  666ddc8d-1dc8-439b-aaef-ae5bf72ac613     Gita Goswami
# 4  2320f8b6-7c7c-44c5-b817-76383dc70562        Dev Singh
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ALm5wu...
# 1  https://play-lh.googleusercontent.com/a-/ACNPE...
# 2  https://play-lh.googleusercontent.com/a/ALm5wu...
# 3  https://play-lh.googleusercontent.com/a/ALm5wu...
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                              content  score  thumbsUpCount  \
# 0  Great concept, but poor execution. My main com...      3            252
# 1  Duo was better!! You could set up a call much ...      1            966
# 2  Great app, I love it. I do really wish it inte...      5            148
# 3  I gave this a four because sometimes the voice...      4            624
# 4  The app crashes on opening. After being opened...      1            986
#
#            reviewCreatedVersion                  at  \
# 0  2022.09.04.473010480.Release 2022-09-30 07:53:14
# 1  2022.07.24.464891844.Release 2022-08-19 04:59:23
# 2  2022.09.04.473010480.Release 2022-10-04 06:19:20
# 3  2022.09.04.473010480.Release 2022-09-23 01:02:47
# 4  2022.08.07.467804210.Release 2022-08-26 12:11:44
#
#                                         replyContent           repliedAt
# 0  Hi there. Make sure your bluetooth headset wor... 2022-09-30 10:19:01
# 1  Hi, Jim. We really appreciate you taking the t... 2022-08-19 05:31:45
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4  Hi, Dev. We really appreciate you taking the t... 2022-08-26 12:27:23
